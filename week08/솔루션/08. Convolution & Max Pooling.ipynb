# %%
import numpy as np
import tensorflow as tf
import matplotlib.pylab as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
# Data Load
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
image = mnist.train.images[99]
plt.imshow(image.reshape(28,28), cmap='gray')
plt.show()

# %% [markdown]
# ## Famous Kernels(Filters)
#
# https://en.wikipedia.org/wiki/Kernel_(image_processing)
#
# 위 링크에 소개된 3x3 필터중에 하나를 골라서, `kernel` 을 선언하여 입력과 출력을 비교해보세요.

# %%
x = tf.placeholder(tf.float32, [None, 784])
x_img = tf.reshape(x, shape=[-1, 28, 28, 1])
# TODO1
kernel = np.array([[0,1,0], [1, -4, 1], [0, 1, 0]]).reshape([3, 3, 1, 1])# edge detection 1
kernel = np.array([[-1,-1,-1], [-1, 8, -1], [-1,-1,-1]]).reshape([3, 3, 1, 1])# edge detection 2
kernel = np.array([[1,1,1], [1, 1, 1], [1,1,1]]).reshape([3, 3, 1, 1]) / 9. # Box Blur
kernel = np.array([[1,2,1], [2, 4, 2], [1,2,1]]).reshape([3, 3, 1, 1]) / 16. # Gaussian Blur

print(kernel.shape)
conv_out = tf.nn.conv2d(x_img, kernel, strides=[1, 1, 1, 1], padding='VALID')

init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)

in_image, out_image = sess.run([x_img, conv_out], feed_dict={x:mnist.train.images[:1]})

plt.figure(figsize=(8,4))
plt.subplot(1,2,1)
plt.imshow(in_image[0,:,:,0], cmap='gray')
plt.title('shape = ({0}, {1})'.format(in_image.shape[1], in_image.shape[2]))

plt.subplot(1,2,2)
plt.imshow(out_image[0,:,:,0], cmap='gray')
plt.title('shape = ({0}, {1})'.format(out_image.shape[1], out_image.shape[2]))
plt.show()
# Out:
# (3, 3, 1, 1)

# %% [markdown]
# ## Stride와 Padding
#
# `strides`와 `padding`을 바꿔보면서, 출력을 `shape`이 어떻게 변하는지 파악해보세요.

# %%
x = tf.placeholder(tf.float32, [None, 784])
x_img = tf.reshape(x, shape=[-1, 28, 28, 1])

# TODO2
conv_out = tf.nn.conv2d(x_img, kernel, strides=[1, 2, 2, 1], padding='SAME')

init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)

in_image, out_image = sess.run([x_img, conv_out], feed_dict={x:mnist.train.images[:1]})

plt.figure(figsize=(8,4))
plt.subplot(1,2,1)
plt.imshow(in_image[0,:,:,0], cmap='gray')
plt.title('shape = ({0}, {1})'.format(in_image.shape[1], in_image.shape[2]))

plt.subplot(1,2,2)
plt.imshow(out_image[0,:,:,0], cmap='gray')
plt.title('shape = ({0}, {1})'.format(out_image.shape[1], out_image.shape[2]))
plt.show()

# %% [markdown]
# ## Max Pooling

# %%
x = tf.placeholder(tf.float32, [None, 784])
x_img = tf.reshape(x, shape=[-1, 28, 28, 1])

# TODO3
max_pooled = tf.layers.max_pooling2d(x_img, 2, 2)

init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)

in_image, out_image = sess.run([x_img, max_pooled], feed_dict={x:mnist.train.images[:1]})

plt.figure(figsize=(8,4))
plt.subplot(1,2,1)
plt.imshow(in_image[0,:,:,0], cmap='gray')
plt.title('shape = ({0}, {1})'.format(in_image.shape[1], in_image.shape[2]))

plt.subplot(1,2,2)
plt.imshow(out_image[0,:,:,0], cmap='gray')
plt.title('shape = ({0}, {1})'.format(out_image.shape[1], out_image.shape[2]))
plt.show()
