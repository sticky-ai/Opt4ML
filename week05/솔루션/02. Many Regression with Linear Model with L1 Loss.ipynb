# %%
import numpy as np
import matplotlib.pylab as plt
from scipy.optimize import minimize
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # Linear Model : Feature와 Labels

# %%
def forward_model(w, x):
    assert w.shape[0] == x.shape[0]
    return w.dot(x)

# %%
def loss_mse(w, feature_set, label_set):
    val = 0.0
    for feature, label in zip(feature_set, label_set):
        val = val + np.abs(forward_model(w, feature) - label)
    val /= len(feature_set)
    return val

# %% [markdown]
# ## 1. Linear Regression Model
# $$
# f(x) = w_0 + w_1x
# $$

# %%
np.random.seed(327)
x = np.linspace(-1,1,50)
y = x + 1.0 + np.random.rand(len(x))

# %%
plt.plot(x, y, 'o')
plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
features1 = np.array([[1., xval] for xval in x])
labels1 = y

# %%
w0 = np.array([0.7, 1])
loss1 = lambda w: loss_mse(w, features1, labels1)
res = minimize(loss1, w0)
print(res)
w1 = res.x
# Out:
#       fun: 0.22160451099200093
#  hess_inv: array([[ 0.20789702, -0.2668378 ],
#        [-0.2668378 ,  0.34248934]])
#       jac: array([0.        , 0.00230585])
#   message: 'Desired error not necessarily achieved due to precision loss.'
#      nfev: 644
#       nit: 8
#      njev: 158
#    status: 2
#   success: False
#         x: array([1.43707124, 0.98911265])

# %%
prediction1 = np.dot(features1, w1)
plt.plot(x, y, 'o')
plt.plot(x, prediction1, '--r')
plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ## 2. Quadratic Regression Model
# $$
# f(x) = w_0 + w_1x + w_2x^2
# $$

# %%
np.random.seed(327)
x = np.linspace(-1,1,50)
y = x**2 + 0.5 * x + 1.0 + 0.5 * np.random.rand(len(x))

# %%
plt.plot(x, y, 'o')
plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
# TODO1
features2 = np.array([[1., xval, xval**2] for xval in x])
labels2 = y

# %%
w0 = np.array([0.7, 1, 0.5])
loss2 = lambda w: loss_mse(w, features2, labels2)
res = minimize(loss2, w0)
print(res)
w2 = res.x
# Out:
#       fun: 0.109277716452602
#  hess_inv: array([[ 1.16223570e+02, -5.29145688e-03, -1.16337040e+02],
#        [-5.29145688e-03,  3.56051832e-07,  5.29880157e-03],
#        [-1.16337040e+02,  5.29880157e-03,  1.16450671e+02]])
#       jac: array([ 0.        , -0.01714286,  0.0011995 ])
#   message: 'Desired error not necessarily achieved due to precision loss.'
#      nfev: 860
#       nit: 15
#      njev: 170
#    status: 2
#   success: False
#         x: array([1.19893778, 0.49820758, 1.04096015])

# %%
prediction2 = np.dot(features2, w2)
plt.plot(x, y, 'o')
plt.plot(x, prediction2, '--r')
plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ## 3. Cubic Regression Model
# $$
# f(x) = w_0 + w_1x + w_2x^2 + w_3x^3
# $$

# %%
np.random.seed(327)
x = np.linspace(-1,1,50)
y = 2*x**3 - .4 * x**2 + .5 * x + 1.0 + 0.5 * np.random.rand(len(x))

# %%
plt.plot(x, y, 'o')
plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
# TODO 2
features3 = np.array([[1, xval, xval**2, xval**3] for xval in x])
labels3 = y

# %%
w0 = np.array([0.0, 0.7, 1, 0.5])
loss3 = lambda w: loss_mse(w, features3, labels3)
res = minimize(loss3, w0)
print(res)
w3 = res.x
# Out:
#       fun: 0.10910570677201718
#  hess_inv: array([[   0.27371365,   -6.66143098,   -0.96347998,    8.0019117 ],
#        [  -6.66143098,  162.1245619 ,   23.44891781, -194.7489815 ],
#        [  -0.96347998,   23.44891781,    3.39262439,  -28.16826706],
#        [   8.0019117 , -194.7489815 ,  -28.16826706,  233.93907732]])
#       jac: array([ 0.        ,  0.03020408, -0.01092878,  0.02300708])
#   message: 'Desired error not necessarily achieved due to precision loss.'
#      nfev: 911
#       nit: 26
#      njev: 151
#    status: 2
#   success: False
#         x: array([ 1.20138056,  0.45060391, -0.36577312,  2.0579799 ])

# %%
prediction3 = np.dot(features3, w3)
plt.plot(x, y, 'o')
plt.plot(x, prediction3, '--r')
plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ## 4. Exponential Regression Model
# \begin{align}
# f(x) &= e^{w_0x}\\
# g(x) &= \ln f(x) = w_0x
# \end{align}

# %%
np.random.seed(327)
x = np.linspace(-1,1,50)
y = np.exp(2 * x) + 0.2 * (2* np.random.rand(len(x))-1)

# %%
plt.plot(x, y, 'o')
plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
features4 = np.array([[xval] for xval in x])
labels4 = np.log(y)

# %%
w0 = np.array([0.2])
loss4 = lambda w: loss_mse(w, features4, labels4)
res = minimize(loss4, w0)
print(res)
w4 = res.x
# Out:
#       fun: 0.16389933388461017
#  hess_inv: array([[2.37515149]])
#       jac: array([0.])
#   message: 'Optimization terminated successfully.'
#      nfev: 144
#       nit: 6
#      njev: 48
#    status: 0
#   success: True
#         x: array([2.00325321])

# %%
prediction4 = np.exp(np.dot(features4, w4))
plt.plot(x, y, 'o')
plt.plot(x, prediction4, '--r')
plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ## 5. Sine/cosine Regression
# $$
# f(x) = w_0\cos(\pi x) + w_1\sin(\pi  x)
# $$

# %%
np.random.seed(327)
x = np.linspace(-1,1,50)
y = 1.0 * np.cos(np.pi * x) + 1.0 * np.sin(np.pi*x) + 2 * np.random.rand(len(x)) - 1

# %%
plt.plot(x, y, 'o')
plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
# TODO 3
features5 = np.array([[np.cos(np.pi * xval), np.sin(np.pi * xval)] for xval in x])
labels5 = y

# %%
w0 = np.array([0.2, 0.7])
loss5 = lambda w: loss_mse(w, features5, labels5)
res = minimize(loss5, w0)
print(res)
w5 = res.x
# Out:
#       fun: 0.45492691011555747
#  hess_inv: array([[ 0.81713979, -0.04108589],
#        [-0.04108589,  0.3529909 ]])
#       jac: array([0.00181885, 0.01259648])
#   message: 'Desired error not necessarily achieved due to precision loss.'
#      nfev: 444
#       nit: 4
#      njev: 108
#    status: 2
#   success: False
#         x: array([0.88712421, 1.03488825])

# %%
prediction5 = np.dot(features5, w5)
plt.plot(x, y, 'o')
plt.plot(x, prediction5, '--r')
plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.show()
